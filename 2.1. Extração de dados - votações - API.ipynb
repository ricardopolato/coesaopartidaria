# %% [markdown]
# ## Extraindo dados de votação de preposições

# %%
import pandas as pd
import pandasql as ps
import numpy as np
import json, requests 
#import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup

# %% [markdown]
# ### Extração dos dados

# %% [markdown]
# Capturando as informações das proposicões votadas por tipo e ano

# %%
def getProposicoes(tipo, ano):
    url_votacoes = "https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ListarProposicoesVotadasEmPlenario?ano="+ano+"&tipo="+tipo
    response = requests.get(url_votacoes)
    dados_req = BeautifulSoup(response.content, 'html.parser')
    dados_req

    codproposicao = []
    nomeproposicao = []
    datavotacao = []
    for row in dados_req.findAll("proposicao"):
        codproposicao.append(row.find('codproposicao').text)
        nomeproposicao.append(row.find('nomeproposicao').text)
        datavotacao.append(row.find('datavotacao').text)

    tipoproposicao = []
    numeroproposicao = []
    anoproposicao = []
    for i in nomeproposicao:
        tipoproposicao.append(i.split(" ")[0])
        numeroproposicao.append(i.split(" ")[1].split("/")[0])
        anoproposicao.append(i.split(" ")[1].split("/")[1])

    proposicoes = pd.DataFrame()
    proposicoes['CodProposicao'] = codproposicao
    proposicoes['TipoProposicao'] = tipoproposicao
    proposicoes['NumeroProposicao'] = numeroproposicao
    proposicoes['AnoProposicao'] = anoproposicao
    proposicoes['DataVotacao'] = datavotacao
    return proposicoes

# %%
from pandasql import sqldf

def getQuery(q):
    pysqldf = lambda q: sqldf(q, globals())
    return pysqldf(q)

# %% [markdown]
# Capturando informações da orientação da bancada

# %%
# capturando informação da orientação da bancada
def orientacaoBancada(dadosxml, codsessao, varprop):
    dados = dadosxml.find('votacao', codsessao=codsessao)
    dataVotacao = dados.get('data')
    objVotacao = dados.get('objvotacao')
    proposicao = varprop
    
    bancada_codSessao = []
    bancada_proposicao = []
    bancada_objvotacao = []
    bancada_data = []
    bancada_partido = []
    bancada_orientacao = []
    
    for row in dados.findAll("orientacaobancada"):
        cells = row.findAll('bancada')
        for tag in cells:
            bancada_partido.append(tag.get('sigla'))
            bancada_orientacao.append(tag.get('orientacao'))
            bancada_objvotacao.append(objVotacao)
            bancada_data.append(dataVotacao)
            bancada_codSessao.append(codsessao)
            bancada_proposicao.append(proposicao)
    
    bancada = pd.DataFrame()
    bancada['CodSessao'] = bancada_codSessao
    bancada['Proposicao'] = bancada_proposicao
    bancada['Bancada'] = bancada_partido
    bancada['Orientacao'] = bancada_orientacao
    bancada['ObjVotacao'] = bancada_objvotacao
    bancada['DataVotacao'] = bancada_data
    return bancada

# %% [markdown]
# Capturando informações da votação dos parlamentares

# %%
# capturando informação da votação
def votosParlamentar(dadosxml, codsessao, varprop):
    dados = dadosxml.find('votacao', codsessao=codsessao)
    dataVotacao = dados.get('data')
    objVotacao = dados.get('objvotacao')
    proposicao = varprop
    
    dep_codSessao = []
    dep_objVotacao = []
    dep_proposicao =[]
    dep_id = []
    dep_data = []
    dep_nome = []
    dep_partido = []
    dep_uf = []
    dep_voto = []
    for row in dadosxml.findAll("votos"):
        cells = row.findAll('deputado')
        for tag in cells:
            dep_id.append(tag.get('idecadastro'))
            dep_nome.append(tag.get('nome'))
            dep_partido.append(tag.get('partido').replace(" ",""))
            dep_uf.append(tag.get('uf'))
            dep_voto.append(tag.get('voto').replace(" ",""))
            dep_codSessao.append(codsessao)
            dep_objVotacao.append(objVotacao)
            dep_data.append(dataVotacao)
            dep_proposicao.append(proposicao)
    
    votacao = pd.DataFrame()
    votacao['CodSessao'] = dep_codSessao
    votacao['Proposicao'] = dep_proposicao
    votacao['IdParlamentar'] = dep_id
    votacao['Parlamentar'] = dep_nome
    votacao['Partido'] = dep_partido
    votacao['Uf'] = dep_uf
    votacao['Voto'] = dep_voto
    votacao['ObjVotacao'] = dep_objVotacao
    votacao['Data'] = dep_data
    return votacao

# %% [markdown]
# Extraindo dados de Orientação da Bancada

# %%
def extraiVotosBancada(df_proposicoes):
    dfOrientacaoBancada = pd.DataFrame(columns=["CodSessao","Bancada","Orientacao","ObjVotacao","DataVotacao"])
    q="""SELECT DISTINCT CodProposicao, TipoProposicao, NumeroProposicao, AnoProposicao FROM proposicoes;"""
    df_proposicoes = getQuery(q)
    for x, y, z in zip(df_proposicoes['TipoProposicao'], df_proposicoes['NumeroProposicao'], df_proposicoes['AnoProposicao']):
        print("----------------")
        print(x,y,z)
        varprop = x + " " + y + " " + z
        url = "https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo="+x+"&numero="+y+"&ano="+z
        header = { 'Accept': 'application/xml' }
        response = requests.get(url)
        dadosxml = BeautifulSoup(response.content, 'html.parser')
        print(url)
        for votacao in dadosxml.findAll("votacoes"):
            linhas = votacao.findAll('votacao')
            for tag in linhas:
                print(tag.get('codsessao'), "-", tag.get('objvotacao'))

                df_orientacao = orientacaoBancada(dadosxml, tag.get('codsessao'), varprop)
                dfOrientacaoBancada = pd.concat([dfOrientacaoBancada, df_orientacao])
    return dfOrientacaoBancada

# %% [markdown]
# Extraindo os dados de Votação do Parlamentar

# %%
def extraiVotosParlamentar(proposicoes):
    dfVotosParlamentares = pd.DataFrame(columns=["CodSessao","IdParlamentar","Parlamentar","Partido","Uf","Voto","ObjVotacao","Data"])
    q="""SELECT DISTINCT CodProposicao, TipoProposicao, NumeroProposicao, AnoProposicao FROM proposicoes;"""
    df_proposicoes = getQuery(q)
    for x, y, z in zip(df_proposicoes['TipoProposicao'], df_proposicoes['NumeroProposicao'], df_proposicoes['AnoProposicao']):
        print("----------------")
        print(x,y,z)
        varprop = x + " " + y + " " + z
        url = "https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo="+x+"&numero="+y+"&ano="+z
        header = { 'Accept': 'application/xml' }
        response = requests.get(url)
        dadosxml = BeautifulSoup(response.content, 'html.parser')
        print(url)
        for votacao in dadosxml.findAll("votacoes"):
            linhas = votacao.findAll('votacao')
            for tag in linhas:
                print(tag.get('codsessao'), "-", tag.get('objvotacao'))

                df_votos = votosParlamentar(dadosxml, tag.get('codsessao'), varprop)
                dfVotosParlamentares = pd.concat([dfVotosParlamentares, df_votos])
    return dfVotosParlamentares

# %% [markdown]
# Extraindo os dados de Proposições

# %%
tipo = ["PEC", "MPV", "PLP", "PL"]
ano = "2019"
proposicoes = pd.DataFrame(columns=["CodProposicao","TipoProposicao","NumeroProposicao","AnoProposicao","DataVotacao"])
for t in tipo:
    proposicoes = pd.concat([proposicoes, getProposicoes(t, ano)])
print("Tipos:", tipo)
proposicoes.head()
# Out:
# Tipos: ['PEC', 'MPV', 'PLP', 'PL']
#   CodProposicao TipoProposicao NumeroProposicao AnoProposicao DataVotacao
# 0        516111            PEC               70          2011  05/06/2019
# 1        516111            PEC               70          2011  05/06/2019
# 2        516111            PEC               70          2011  05/06/2019
# 3        946494            PEC                2          2015  26/03/2019
# 4        946494            PEC                2          2015  26/03/2019

# %%
dfVotosParlamentares = extraiVotosParlamentar(proposicoes)
# Out:
# ----------------
# PEC 70 2011
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PEC&numero=70&ano=2011
# 16828 - EMENDA AGLUTINATIVA Nº 1
# 16828 - PROPOSTA DE EMENDA À CONSTITUIÇÃO - 2º TURNO
# 16828 - EMENDA DE REDAÇÃO Nº 1
# ----------------
# PEC 2 2015
# /Users/Polato/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PEC&numero=2&ano=2015
# 16761 - PROPOSTA DE EMENDA À CONSTITUIÇÃO - SEGUNDO TURNO
# 16761 - DTQ. 1 - BLOCO PSL - §11 DO ART. 165, CONST. DO ART. 1º DO SUBSTITUTIVO
# 16761 - DTQ. 2 - BLOCO PSL - EXP. "NOS TERMOS DE LEI COMPLEMENTAR", ...
# 16761 - SUBSTITUTIVO DA COMISSÃO ESPECIAL
# 16761 - EMENDAS DE REDAÇÃO DE NºS 1 A 4
# ----------------
# PEC 372 2017
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PEC&numero=372&ano=2017
# 16955 - PROPOSTA DE EMENDA À CONSTITUIÇÃO - PRIMEIRO TURNO
# 16983 - PROPOSTA DE EMENDA A CONSTITUIÇÃO - SEGUNDO TURNO
# 16983 - DTQ 1 - PL - EXP: "ALÉM DE OUTRAS ATRIBUIÇÕES..."
# ----------------
# PEC 391 2017
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PEC&numero=391&ano=2017
# 17027 - EMENDA Nº 1
# 17027 - REQUERIMENTO DE RETIRADA DE PAUTA
# 17027 - PROPOSTA DE EMENDA À CONSTITUIÇÃO - PRIMEIRO TURNO
# 17027 - PROPOSTA DE EMENDA À CONSTITUIÇÃO - PRIMEIRO TURNO
# 17027 - PREFERÊNCIA P/ VOTAÇÃO DA PEC Nº 215/16
# ----------------
# PEC 6 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PEC&numero=6&ano=2019
# 16887 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16887 - PROPOSTA DE EMENDA À CONSTITUIÇÃO - SEGUNDO TURNO
# 16860 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16863 - DTQ 2 - CIDADANIA - § ÚNICO DO ART. 203 DA CONSTITUIÇÃO FEDERAL
# 16862 - DTQ 9 - PL - EMENDA Nº 176
# 16866 - DTQ 11 - PT - ART. 26 DO SUBSTITUTIVO
# 16866 - DTQ 12 - PT - ART. 23 DO SUBSTITUTIVO
# 16866 - DTQ 13 - PT - §2º DO ART. 26 DO SUBSTITUTIVO
# 16864 - DTQ 14 - PSOL - §3º DO ART. 239, CONST. DO ART. 1º DO SUBSTITUTIVO
# 16861 - CONSULTA AO PLENÁRIO SOBRE VOTAÇÃO PARCELADA
# 16865 - DTQ 43 - PDT - EXP. " EM DOIS ANOS" CONST. DO §1º, DO ART. 20...
# 16865 - DTQ 44 - PDT - INC. IV DO ART. 20 DO SUBSTITUTIVO
# 16861 - REQ. DE VOTAÇÃO EM GLOBO DA ADMISSIBILIDADE DOS DESTAQUES SIMPLES
- REQUERIMENTO DE VOTAÇÃO ARTIGO POR ARTIGO
# 16752 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16752 - REQUERIMENTO DE VOTAÇÃO NOMINAL DO REQ. DE RETIRADA DE PAUTA
# 16761 - DTQ 15 - PSOL - EXP "181" CONST. DO INC. III, DO ART. 10 DO SUBSTITUTIVO
# 16755 - DTQ 23 - PT - EMENDA DE PLENÁRIO Nº 17
# 16754 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16753 - REQUERIMENTO DE ENCERRAMENTO DA DISCUSSÃO E DO ENCAMINHAMENTO
# 16753 - REQUERIMENTO DE ENCERRAMENTO DA DISCUSSÃO E DO ENCAMINHAMENTO
# 16755 - DTQ 28 - BLOCO PDT - EMENDA DE PLENÁRIO Nº 3
# 16754 - SUBEMENDA SUBSTITUTIVA GLOBAL DE PLENÁRIO
# 16754 - VOTAÇÃO DA ADMISSIBILIDADE, EM GLOBO, DOS DESTAQUES SIMPLES
# 16754 - DTQ 31 - NOVO - EXP "BRASILEIROS MEDIANTE CONTRATO DE TRABALHO...."
# 16760 - DTQ 33 - PPS - EXP "ESTABELECIDOS NA LEGISLAÇÃO E REGULAMENTAÇÃO...."
# 16755 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16760 - DTQ 35 - BLOCO PSL- EMENDA DE PLENÁRIO Nº 15
# ----------------
# PL 4067 2015
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=4067&ano=2015
# 16996 - REQUERIMENTO DE RETIRADA DE PAUTA
# ----------------
# PL 5082 2016
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=5082&ano=2016
# 17001 - DTQ 2 - PSL - EMENDA DE PLENÁRIO Nº 2
# ----------------
# PL 7596 2017
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=7596&ano=2017
# 16896 - DTQ. 2 - PSL - ART.4º DO PL
# ----------------
# PL 8240 2017
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=8240&ano=2017
# 16859 - PROJETO DE LEI
# 16859 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16858 - REQ. DE VOT. NOMINAL DO REQ. DE ADIAMENTO DA VOTAÇÃO POR 2 SESSÕES
# 16902 - DTQ 2 - PT - §1º DO ART. 1º DO PL Nº 6.298/2016 APENSADO
# 16859 - REQ. DE VOTAÇÃO EM GLOBO DA ADMISSIBILIDADE DOS DESTAQUES SIMPLES
# 16859 - REQUERIMENTO DE VOTAÇÃO ARTIGO POR ARTIGO
# 16859 - VOTAÇÃO EM GLOBO  DA ADMISSIBILIDADE DOS DESTAQUES SIMPLES
# 16902 - DTQ 6 - PT - EXP "E ESPORTIVAS", CONST. DO ART. 1º DA LEI 13.364/16...
# 16902 - DTQ 4 - PT - ART. 4º DO PL 8.240/17
# ----------------
# PL 10372 2018
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=10372&ano=2018
# 17009 - SUBSTITUTIVO DA COMISSÃO ESPECIAL
# 17009 - DTQ 1 - NOVO - ART. 3º-B, CONST. ART. 3º DO SUBSTITUTIVO
# ----------------
# PL 10431 2018
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=10431&ano=2018
# 16727 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16727 - REQUERIMENTO DE ADIAMENTO DA DISCUSSÃO POR 2 SESSÕES
# ----------------
# PL 10985 2018
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=10985&ano=2018
# 16845 - REQUERIMENTO DE VOTAÇÃO NOMINAL DO REQ. DE RETIRADA DE PAUTA
# 16845 - DTQ 4 - NOVO - ART. 3º DO PL 10.985/2018
# 16846 - DTQ 6 - PSL - ART. 4º DO PL 10.985/2018
# ----------------
# PL 5029 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=5029&ano=2019
# 16930 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16931 - REQUERIMENTO DE VOTAÇÃO DAS EMENDAS UMA A UMA
# 16931 - DTQ 1: NOVO - EMENDA SUPRESSIVA DO SENADO FEDERAL, QUE SUPRIMIU O ART. 44...
# 16930 - REQUERIMENTO DE ADIAMENTO DA DISCUSSÃO POR 2 SESSÕES
# 16931 - DTQ 2: PSL - EMENDA DO SENADO FEDERAL QUE SUPRIME O INCISO X DO ART. 44...
# 16931 - DTQ 3: PSL - EMENDA DO SENADO FEDERAL QUE SUPRIME O ART. 11 DA LEI Nº 9504/97
# 16931 - DTQ 4: PSL - EMENDA DO SENADO FEDERAL QUE SUPRIME O INCISO VIII DO ART. 44...
# 16930 - REQUERIMENTO DE ADIAMENTO DA VOTAÇÃO POR 2 SESSÕES
# 16931 - DTQ 5: PSOL - VOTAÇÃO DA EMENDA SUPRESSIVA  REFERENTE AO ART. 26...
# 16931 - DTQ 6: CIDADANIA - EMENDA DO SF QUE SUPRIME O PARÁGRAFO ÚNICO DO ART. 18-A...
# 16931 - DTQ 7: PODEMOS - EMENDA SUPRESSIVA REFERENTE AO PARÁGRAFO ÚNICO DO ART. 3º...
# 16931 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16931 - EMENDAS SUPRESSIVAS COM PARECER PELA REJEIÇÃO
# ----------------
# PL 1321 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=1321&ano=2019
# 16768 - DTQ 5 - NOVO - EMENDA  Nº 4
# 16788 - DTQ. 3 - PT - EMENDA Nº 1 DO SENADO FEDERAL
# ----------------
# PL 2787 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=2787&ano=2019
# 16843 - REQUERIMENTO DE RETIRADA DE PAUTA
# ----------------
# PL 2788 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=2788&ano=2019
# 16844 - SUBSTITUTIVO DA CCJ
# 16843 - REQUERIMENTO DE ADIAMENTO DA DISCUSSÃO POR 2 SESSÕES
# ----------------
# PL 2999 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=2999&ano=2019
# 16909 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16915 - REQUERIMENTO DE VOTAÇÃO ARTIGO POR ARTIGO
# 16909 - REQUERIMENTO DE ADIAMENTO DA DISCUSSÃO POR 2 SESSÕES
# 16910 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16915 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16915 - EMENDAS COM PARECER PELA APROVAÇÃO - ART. 1, 3, 4, 5, 7 DO SUBST.
# ----------------
# PL 3261 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=3261&ano=2019
# 17017 - REQUERIMENTO DE RETIRADA DE PAUTA
# 17018 - REQUERIMENTO DE VOTAÇÃO DAS EMENDAS UMA A UMA
# 17018 - REQUERIMENTO DE VOTAÇÃO ARTIGO POR ARTIGO
# 17018 - VOTAÇÃO DA ADMISSIBILIDADE EM GLOBO DOS DESTAQUES SIMPLES
# 17018 - REQ. DE VOTAÇÃO EM GLOBO DA ADMISSIBILIDADE DOS DESTAQUES SIMPLES
# 17018 - DTQ. 15 - DEM - PREFERÊNCIA PARA O PL Nº 4.162/2019
# 17017 - REQUERIMENTO DE ENCERRAMENTO DA DISCUSSÃO E DO ENCAMINHAMENTO
# 17018 - REQUERIMENTO DE RETIRADA DE PAUTA
# 17018 - EMENDAS COM PARECER PELA APROVAÇÃO, Nºs 15,16,17, 23
# 17018 - EMENDAS COM PARECER PELA APROVAÇÃO, Nºs 15,16,17, 23
# 17025 - REQUERIMENTO DE RETIRADA DE PAUTA
# 17025 - DTQ 21 - PT - ART. 11 DA EMENDA Nº 17
# 17026 - DTQ 1 - PCdoB - ART. 15 DO SUBSTITUTIVO
# 17026 - DTQ 4 - PT - EMENDA Nº 7
# 17026 - DTQ 17 - REPUBLICANOS - EMENDA Nº 18
# 17026 - REQUERIMENTO DE RETIRADA DE PAUTA
# ----------------
# PL 3723 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=3723&ano=2019
# 16980 - REQUERIMENTO DE ADIAMENTO DA VOTAÇÃO POR 2 SESSÕES
# 16972 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16975 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16980 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16980 - REQUERIMENTO DE ADIAMENTO DA VOTAÇÃO POR 1 SESSÃO
# 16981 - SUBEMENDA SUBSTITUTIVA GLOBAL
# ----------------
# PL 3715 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=3715&ano=2019
# 16905 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16905 - REQUERIMENTO DE ENCERRAMENTO DA DISCUSSÃO E DO ENCAMINHAMENTO
# 16904 - REQUERIMENTO DE RETIRADA DE PAUTA
# 16904 - REQUERIMENTO DE ADIAMENTO DA DISCUSSÃO POR 2 SESSÕES
# 16905 - REQUERIMENTO DE ADIAMENTO DA VOTAÇÃO POR 2 SESSÕES
# 16905 - REQUERIMENTO DE VOTAÇÃO ARTIGO POR ARTIGO
# 16905 - REQUERIMENTO DE VOTAÇÃO DAS EMENDAS UMA A UMA
# 16904 - CONSULTA AO INDEFERIMENTO DE REQ. DE DISCUSSÃO PARCELADA
# 16905 - PROJETO DE LEI
# ----------------
# PL 4121 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=4121&ano=2019
# 16943 - DTQ 3 - PSL - EMENDA DE PLENÁRIO Nº 2
# ----------------
# PL 4162 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=4162&ano=2019
# 17018 - DTQ. 13 - PSOL - ART. 50  DA LEI 11.445/2007, COM A REDAÇÃO DADA P/ ART. 8º...
# 17018 - DTQ. 14 - SD - EMENDA Nº 12
# 17018 - DTQ. 18 - CIDADANIA - ART. 54 DA LEI Nº 12.305/2010
# 17018 - PROJETO DE LEI
# 17018 - DTQ. 23 - BL. PP/MDB/PTB - EX. "E DE RESOLUÇÃO DE PASSIVOS DE POLUIÇÃO...
# ----------------
# PL 4805 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=4805&ano=2019
# 17001 - DTQ 1 - DEM - EMENDA DE PLENÁRIO Nº 1
# ----------------
# PL 5815 2019
# https://www.camara.leg.br/SitCamaraWS/Proposicoes.asmx/ObterVotacaoProposicao?tipo=PL&numero=5815&ano=2019
# 17008 - SUBSTITUTIVO DA CCULT
# 17008 - REQUERIMENTO DE ADIAMENTO DA VOTAÇÃO POR 2 SESSÕES
# 17008 - REQUERIMENTO DE VOTAÇÃO ARTIGO POR ARTIGO

# %%
dfVotosParlamentares.head()
# Out:
#   CodSessao      Data IdParlamentar                ObjVotacao  \
# 0     16828  5/6/2019        141417  EMENDA AGLUTINATIVA Nº 1
# 1     16828  5/6/2019        204465  EMENDA AGLUTINATIVA Nº 1
# 2     16828  5/6/2019        178959  EMENDA AGLUTINATIVA Nº 1
# 3     16828  5/6/2019        160531  EMENDA AGLUTINATIVA Nº 1
# 4     16828  5/6/2019        204468  EMENDA AGLUTINATIVA Nº 1
#
#          Parlamentar Partido   Proposicao  Uf Voto
# 0         Edio Lopes      PL  PEC 70 2011  RR  Sim
# 1  Haroldo Cathedral     PSD  PEC 70 2011  RR  Sim
# 2    Hiran Gonçalves      PP  PEC 70 2011  RR  Sim
# 3  Jhonatan de Jesus     PRB  PEC 70 2011  RR    -
# 4   Joenia Wapichana    REDE  PEC 70 2011  RR  Sim

# %%
ano_list = []
for i in dfVotosParlamentares['Data']:
    ano_list.append(i.split('/')[2])
dfVotosParlamentares['Ano'] = ano_list

# %%
# Removendo votação que possa não ter ocorrido no ano selecionado
dfVotosParlamentares = dfVotosParlamentares.query("Ano=='"+ano+"'")

# %%
print("Base de dados do ano de", ano, "contém", dfVotosParlamentares.shape[0], "linhas e", dfVotosParlamentares.shape[1], "colunas.")
# Out:
# Base de dados do ano de  2019 contém 2250300 linhas e 10 colunas.

# %%
#Exportando para csv
dfVotosParlamentares.to_csv('dados/votos_2019.csv', sep=';', index=False)
